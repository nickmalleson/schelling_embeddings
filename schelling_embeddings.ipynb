# %% [markdown]
# # Embeddings with the Schelling Model
#
# A series of experiements with using embeddings to define agents in a simple schelling model.
#
# See [schelling_embeddings2.py](schelling_embeddings2.py) for the Schelling model code.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import os

# Import the SchellingModel from your existing code file
from src.schelling_embeddings.model import SchellingModel

# %% [markdown]
# ## Household Embedding similarity
#
# Explore the embeddings before running the model later.

# %% [markdown]
# ### Embedding example
#
# Begin by doing some analysis of a few example embeddings used for demonstrative purposes

# %%
example_descriptions = pd.read_csv("household_descriptions/household_descriptions-example.csv", header=None)[0].to_list()
example_descriptions
# Out:
# ['A retired couple living alone in a semi-detached house in a suburban area, relying on state pensions and modest savings, strongly supporting the Conservative party',
#  'An elderly couple residing in a suburban, semi-detached house, drawing income from their savings and their state pensions, voting for the Conservative party consistently',
#  'A young, single professional renting a studio flat in a city centre, earning a salary around £35,000 from a career in marketing, voting for the Liberal Democrats and actively campaigning for environmental causes',
#  'A large, multi-generational family residing in a terraced house, with the patriarch working as a manual labourer on a zero-hours contract, the matriarch a part-time carer, and several children, identifying as Labour supporters and strongly union-backed',
#  'A single parent with three children, living in a council flat, surviving on a tight budget that includes Universal Credit and Child Tax Credits, and staunchly supporting the Labour party, particularly its more left-wing elements']

# %% [markdown]
# Calculate and examine the embeddings for those descriptions

# %%
# Create a minimal model instance that doesn't run the main loop, but still loads embeddings.
model = SchellingModel(
    descriptions=example_descriptions,
    grid_size=1,
    num_agents=1,
    similarity_threshold=0.85,
    max_iters=0
)

# Retrieve the  household embeddings from the model
embeddings = model.description_embeddings

# Compute the similarity matrix
sim_matrix = cosine_similarity(embeddings)

# Plot the similarity matrix
plt.imshow(sim_matrix)  # By default uses a color scale
plt.colorbar()
plt.title("Cosine Similarities Between Household Types")
plt.xlabel("Household Type Index")
plt.ylabel("Household Type Index")
plt.savefig(os.path.join("results", "similarity_matrix_example.pdf"), bbox_inches='tight', dpi=128)
plt.show()
# Out:
# Embedding shape: (5, 384)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %% [markdown]
# Have a look at what a one of those embeddings actually looks like:

# %%
np.set_printoptions(suppress=True, precision=4)
print(embeddings[0])
plt.hist(embeddings[0], bins=30)  # adjust bins as needed
plt.show()
# Out:
# [ 0.0582  0.0465 -0.0171  0.0325  0.015   0.0801 -0.0338 -0.0202 -0.1017
#  -0.0329  0.0137  0.0099  0.0267 -0.0568  0.0363  0.0075 -0.0335 -0.0844
#  -0.0282  0.0848 -0.1162 -0.0092  0.0142  0.0262  0.1303 -0.0071  0.0238
#   0.0377  0.0366  0.0729  0.1507 -0.0046 -0.0669  0.007   0.0092  0.0628
#  -0.007   0.0547 -0.016  -0.0123 -0.0348 -0.0381  0.0575 -0.0149 -0.0823
#  -0.0011 -0.0379 -0.009   0.0425 -0.0375 -0.0012  0.0642 -0.0166 -0.0086
#   0.0275  0.0412 -0.0077 -0.0141 -0.0474 -0.0134  0.0785  0.0152  0.0134
#  -0.0259  0.014  -0.0191  0.0254  0.0631  0.0511 -0.0964 -0.063   0.0146
#  -0.1051 -0.004   0.017  -0.0292  0.0079 -0.0117  0.0823 -0.0638 -0.0316
#  -0.0021 -0.0258 -0.0112 -0.0142  0.0182 -0.0023  0.0118  0.011  -0.0286
#  -0.0358  0.0745  0.028  -0.0322 -0.037  -0.0011 -0.0265 -0.0318 -0.1018
#   0.1178 -0.0648  0.0235  0.0482  0.0088 -0.0028 -0.0181  0.007   0.0343
#   0.0347  0.0161 -0.0154 -0.0567 -0.0633  0.0698  0.0341 -0.1042 -0.0139
#  -0.1053  0.0973 -0.058  -0.0064 -0.0322 -0.0143 -0.0512  0.0819 -0.0045
#   0.0252 -0.      0.0552  0.073  -0.0348  0.0895 -0.0377  0.0464 -0.0655
#   0.0082 -0.0577  0.0236  0.0768  0.0412  0.0164 -0.0317 -0.0176 -0.0592
#  -0.0512  0.0659 -0.0011  0.0112  0.005   0.1703 -0.0131  0.0177  0.0096
#  -0.1498  0.0413  0.1136 -0.0571  0.0102  0.0194  0.0613  0.0246 -0.0866
#   0.0276 -0.0387 -0.0647 -0.0306 -0.0754  0.0319 -0.0555 -0.0018  0.0796
#  -0.0039 -0.0442  0.0312  0.0849  0.0108 -0.056   0.0239 -0.0127  0.0501
#  -0.1361  0.0458 -0.0581 -0.0106 -0.0718 -0.0341  0.0552 -0.1094  0.043
#  -0.035  -0.0802 -0.0674  0.0312 -0.0049 -0.0501 -0.0187  0.0172  0.0437
#   0.0624  0.0408  0.0255 -0.0585 -0.0004 -0.0187 -0.0369 -0.0296  0.0268
#   0.038   0.0203 -0.036   0.0087  0.0568  0.0772  0.0522  0.0051 -0.0218
#  -0.058   0.0208  0.0231  0.0082  0.0021 -0.1148  0.0611 -0.     -0.0279
#   0.0061 -0.0159 -0.0007  0.1109 -0.0067 -0.0411 -0.0843  0.0626  0.0615
#  -0.0441 -0.018   0.0919  0.044  -0.0346 -0.0555  0.0266 -0.0787  0.0618
#   0.0301  0.0396  0.0165  0.0278  0.0912  0.0362  0.0332 -0.0342 -0.0296
#  -0.0689 -0.0924 -0.0107 -0.0118 -0.0409 -0.0624 -0.0368 -0.0715 -0.1137
#  -0.0527 -0.038  -0.0193  0.0202 -0.0094  0.0246  0.053   0.0422 -0.0206
#  -0.04   -0.0587 -0.0264  0.0546  0.0285  0.029  -0.0662 -0.0013 -0.0148
#  -0.0937  0.0196  0.0701  0.0056  0.0562 -0.0244  0.0386 -0.0099  0.0823
#  -0.0117  0.0177 -0.0391 -0.0264  0.0598  0.0016 -0.0047 -0.0823  0.0019
#  -0.0629  0.0778  0.0199  0.0229 -0.0307  0.0742  0.0576 -0.0458 -0.0235
#  -0.0222 -0.0679 -0.0138 -0.0856 -0.0574 -0.0193 -0.0179  0.0555  0.0016
#   0.0232  0.0287 -0.032   0.0321 -0.      0.0893  0.0358 -0.0743 -0.0692
#  -0.044  -0.0194  0.1063 -0.0728  0.002   0.0746  0.0379  0.0269  0.0343
#  -0.0093 -0.0678 -0.0241  0.018   0.0267 -0.1278  0.0554  0.0035 -0.0466
#  -0.0329  0.1582 -0.0323  0.026   0.0437  0.0014  0.1035  0.0571  0.0071
#   0.0313 -0.0218  0.0036 -0.0153  0.0441  0.0729  0.0666  0.0177  0.0452
#  -0.022  -0.0581 -0.0644 -0.0022  0.0229  0.0531  0.0043 -0.0316 -0.123
#  -0.0038  0.0115  0.0342 -0.034   0.0444 -0.016  -0.0425 -0.0246 -0.0037
#   0.0123 -0.0532 -0.01    0.033   0.0044  0.0642]

# %%
# Create a list of (type_i, type_j, similarity) for all unique pairs
pairs = []
for i in range(len(example_descriptions)):
    for j in range(i+1, len(example_descriptions)):
        pairs.append((i, j, sim_matrix[i][j]))

# Sort by similarity
pairs.sort(key=lambda x: x[2], reverse=True)

# Take the top 2 most similar
top_5 = pairs[:2]
# Take the bottom 5 least similar
bottom_5 = pairs[-2:]

# Convert to DataFrame
columns = ["Type1 Index", "Type2 Index", "Similarity", "Type1 Description", "Type2 Description"]
rows = []
for (i, j, sim) in top_5:
    rows.append((i, j, sim, example_descriptions[i], example_descriptions[j]))
for (i, j, sim) in bottom_5:
    rows.append((i, j, sim, example_descriptions[i], example_descriptions[j]))

df = pd.DataFrame(rows, columns=columns)

# Print a latex version of the table
print(df.to_latex(index=False, escape=False, column_format='r|r|r|l|l', float_format="%.2f"))

# Show the table
df
# Out:
# \begin{tabular}{r|r|r|l|l}
# \toprule
# Type1 Index & Type2 Index & Similarity & Type1 Description & Type2 Description \\
# \midrule
# 0 & 1 & 0.82 & A retired couple living alone in a semi-detached house in a suburban area, relying on state pensions and modest savings, strongly supporting the Conservative party & An elderly couple residing in a suburban, semi-detached house, drawing income from their savings and their state pensions, voting for the Conservative party consistently \\
# 3 & 4 & 0.55 & A large, multi-generational family residing in a terraced house, with the patriarch working as a manual labourer on a zero-hours contract, the matriarch a part-time carer, and several children, identifying as Labour supporters and strongly union-backed & A single parent with three children, living in a council flat, surviving on a tight budget that includes Universal Credit and Child Tax Credits, and staunchly supporting the Labour party, particularly its more left-wing elements \\
# 2 & 3 & 0.26 & A young, single professional renting a studio flat in a city centre, earning a salary around £35,000 from a career in marketing, voting for the Liberal Democrats and actively campaigning for environmental causes & A large, multi-generational family residing in a terraced house, with the patriarch working as a manual labourer on a zero-hours contract, the matriarch a part-time carer, and several children, identifying as Labour supporters and strongly union-backed \\
# 1 & 2 & 0.24 & An elderly couple residing in a suburban, semi-detached house, drawing income from their savings and their state pensions, voting for the Conservative party consistently & A young, single professional renting a studio flat in a city centre, earning a salary around £35,000 from a career in marketing, voting for the Liberal Democrats and actively campaigning for environmental causes \\
# \bottomrule
# \end{tabular}
#    Type1 Index  Type2 Index  Similarity  \
# 0            0            1    0.816330
# 1            3            4    0.548173
# 2            2            3    0.260055
# 3            1            2    0.236308
#
#                                    Type1 Description  \
# 0  A retired couple living alone in a semi-detach...
# 1  A large, multi-generational family residing in...
# 2  A young, single professional renting a studio ...
# 3  An elderly couple residing in a suburban, semi...
#
#                                    Type2 Description
# 0  An elderly couple residing in a suburban, semi...
# 1  A single parent with three children, living in...
# 2  A large, multi-generational family residing in...
# 3  A young, single professional renting a studio ...

# %% [markdown]
# Note: **the plots showing the initial and final agent locations** for these example descriptions are generated by running [schelling_embeddings2.py](schelling_embeddings2.py) and then saving them manually.

# %% [markdown]
# ### Full embedding set
#
# Read a few hundred household descriptions produced by [create_household_descriptions.py](household_descriptions/create_household_descriptions.py).

# %%
# Read the CSV file
csv_file = os.path.join("household_descriptions", "household_descriptions-350.csv")
print(f"Reading files: {csv_file}")

household_descriptions_df = pd.read_csv(csv_file, header=None)
# Name the first column 'description' and any other columns can be blank
household_descriptions_df.columns = ['description'] + [f'Unnamed: {i}' for i in range(1, len(household_descriptions_df.columns))]
household_descriptions_df
# Out:
# Reading files: household_descriptions/household_descriptions-350.csv
#                                            description
# 0    Retired couple living in a semi-detached house...
# 1    Single mother with two children, residing in a...
# 2    Family of four with two working parents, livin...
# 3    Shared house with five students, located in a ...
# 4    Older single person living in a terraced house...
# ..                                                 ...
# 345  Older single person living in a terraced house...
# 346  Couple with two children, residing in a large ...
# 347  Family of four with a single working parent, l...
# 348  Retired couple living in a bungalow, with a co...
# 349  Couple with three children, living in a large ...
#
# [350 rows x 1 columns]

# %%
# Need to work with a list from now on
household_descriptions = household_descriptions_df['description'].to_list()

# %% [markdown]
# Calculate the embeddings

# %%
# Create a minimal model instance. Set grid_size=1, num_agents=1, max_iters=0
# so it doesn't run the main loop, but still loads embeddings.
model = SchellingModel(
    descriptions=household_descriptions,
    grid_size=1,
    num_agents=1,
    similarity_threshold=0.85,
    max_iters=0
)

# Retrieve the 10 household embeddings from the model
embeddings = model.description_embeddings

# Compute the similarity matrix
sim_matrix = cosine_similarity(embeddings)
# Out:
# Embedding shape: (350, 384)

# %% [markdown]
# Plot the similarity matrix (a bit big for anything meaningful)

# %%
# Plot the similarity matrix
plt.imshow(sim_matrix)  # By default uses a color scale
plt.colorbar()
plt.title("Cosine Similarities Between Household Types")
plt.xlabel("Household Type Index")
plt.ylabel("Household Type Index")
plt.show()

# %% [markdown]
# Show the most- and least-similar pairs of households

# %%
# Create a list of (type_i, type_j, similarity) for all unique pairs
pairs = []
for i in range(len(household_descriptions)):
    for j in range(i+1, len(household_descriptions)):
        pairs.append((i, j, sim_matrix[i][j]))

# Sort by similarity
pairs.sort(key=lambda x: x[2], reverse=True)

# Take the top 5 most similar
top_5 = pairs[:5]
# Take the bottom 5 least similar
bottom_5 = pairs[-5:]

# Convert to DataFrame
columns = ["Type1 Index", "Type2 Index", "Similarity", "Type1 Description", "Type2 Description"]
rows = []
for (i, j, sim) in top_5:
    rows.append((i, j, sim, household_descriptions[i], household_descriptions[j]))
for (i, j, sim) in bottom_5:
    rows.append((i, j, sim, household_descriptions[i], household_descriptions[j]))

df = pd.DataFrame(rows, columns=columns)

# Show the table
df
# Out:
#    Type1 Index  Type2 Index  Similarity  \
# 0          180          210    0.999601
# 1          219          254    0.999590
# 2          212          238    0.999522
# 3          186          212    0.999503
# 4          210          242    0.999488
# 5           55          133    0.425754
# 6            1           27    0.424936
# 7           55          263    0.423309
# 8            1           55    0.422988
# 9           55          237    0.422975
#
#                                    Type1 Description  \
# 0  Couple with three children, living in a large ...
# 1  Couple with two children, residing in a large ...
# 2  Family of five with two working parents, resid...
# 3  Family of five with two working parents, resid...
# 4  Couple with three children, living in a large ...
# 5  Group of five friends sharing a large house, w...
# 6  Single mother with two children, residing in a...
# 7  Group of five friends sharing a large house, w...
# 8  Single mother with two children, residing in a...
# 9  Group of five friends sharing a large house, w...
#
#                                    Type2 Description
# 0  Couple with three children, living in a large ...
# 1  Couple with two children, residing in a large ...
# 2  Family of five with two working parents, resid...
# 3  Family of five with two working parents, resid...
# 4  Couple with three children, living in a large ...
# 5  Single mother with one child, living in a smal...
# 6  Group of five friends sharing a large house, w...
# 7  Single mother with one child, living in a smal...
# 8  Group of five friends sharing a large house, w...
# 9  Single mother with one child, living in a smal...

# %% [markdown]
# ## Run the model
#
# Run he model, visualise the changing locations of the agents and then plot a graph to show how happiness changes.

# %%
# --- Step 2: Create and run the model
model = SchellingModel(household_descriptions,
                       grid_size=20,
                       num_agents=300,
                       similarity_threshold=0.75,
                       max_iters=200,
                       color_method="pca")

# Save initial positions before running the simulation
initial_positions = [(agent.pos, agent.desc_idx) for agent in model.agents]

# Run the simulation (updates agent positions)
model.run(do_plots=False)

# Save final positions
final_positions = [(agent.pos, agent.desc_idx) for agent in model.agents]

# --- Step 3: Plotting function
def plot_agent_positions(agent_data, title, rgb_map, grid_size=20):
    img = np.ones((grid_size, grid_size, 3))  # white background
    for (x, y), desc_idx in agent_data:
        rgb = rgb_map[desc_idx]
        scaled = (rgb - rgb_map.min()) / (rgb_map.max() - rgb_map.min())
        img[x, y] = scaled
    plt.imshow(img)
    plt.title(title)
    plt.axis("off")
    plt.savefig(f"results/{title.replace(" ", "_")}.pdf", bbox_inches='tight', dpi=128)
    plt.show()

# --- Step 4: Show both grids
plot_agent_positions(initial_positions, "Initial Agent Locations", model.rgb_map)
plot_agent_positions(final_positions, "Final Agent Locations", model.rgb_map)
# Out:
# Embedding shape: (350, 384)
# Iteration 0: 70 happy agents
# Iteration 1: 92 happy agents
# Iteration 2: 87 happy agents
# Iteration 3: 114 happy agents
# Iteration 4: 124 happy agents
# Iteration 5: 131 happy agents
# Iteration 6: 122 happy agents
# Iteration 7: 122 happy agents
# Iteration 8: 120 happy agents
# Iteration 9: 132 happy agents
# Iteration 10: 134 happy agents
# Iteration 11: 138 happy agents
# Iteration 12: 145 happy agents
# Iteration 13: 141 happy agents
# Iteration 14: 143 happy agents
# Iteration 15: 155 happy agents
# Iteration 16: 162 happy agents
# Iteration 17: 151 happy agents
# Iteration 18: 157 happy agents
# Iteration 19: 166 happy agents
# Iteration 20: 160 happy agents
# Iteration 21: 167 happy agents
# Iteration 22: 186 happy agents
# Iteration 23: 187 happy agents
# Iteration 24: 174 happy agents
# Iteration 25: 169 happy agents
# Iteration 26: 170 happy agents
# Iteration 27: 177 happy agents
# Iteration 28: 169 happy agents
# Iteration 29: 185 happy agents
# Iteration 30: 182 happy agents
# Iteration 31: 171 happy agents
# Iteration 32: 179 happy agents
# Iteration 33: 175 happy agents
# Iteration 34: 183 happy agents
# Iteration 35: 187 happy agents
# Iteration 36: 178 happy agents
# Iteration 37: 180 happy agents
# Iteration 38: 182 happy agents
# Iteration 39: 189 happy agents
# Iteration 40: 191 happy agents
# Iteration 41: 201 happy agents
# Iteration 42: 209 happy agents
# Iteration 43: 203 happy agents
# Iteration 44: 206 happy agents
# Iteration 45: 202 happy agents
# Iteration 46: 195 happy agents
# Iteration 47: 198 happy agents
# Iteration 48: 196 happy agents
# Iteration 49: 193 happy agents
# Iteration 50: 203 happy agents
# Iteration 51: 196 happy agents
# Iteration 52: 195 happy agents
# Iteration 53: 203 happy agents
# Iteration 54: 206 happy agents
# Iteration 55: 206 happy agents
# Iteration 56: 201 happy agents
# Iteration 57: 199 happy agents
# Iteration 58: 199 happy agents
# Iteration 59: 196 happy agents
# Iteration 60: 201 happy agents
# Iteration 61: 198 happy agents
# Iteration 62: 202 happy agents
# Iteration 63: 205 happy agents
# Iteration 64: 206 happy agents
# Iteration 65: 219 happy agents
# Iteration 66: 217 happy agents
# Iteration 67: 210 happy agents
# Iteration 68: 212 happy agents
# Iteration 69: 211 happy agents
# Iteration 70: 210 happy agents
# Iteration 71: 218 happy agents
# Iteration 72: 213 happy agents
# Iteration 73: 214 happy agents
# Iteration 74: 219 happy agents
# Iteration 75: 221 happy agents
# Iteration 76: 224 happy agents
# Iteration 77: 233 happy agents
# Iteration 78: 237 happy agents
# Iteration 79: 235 happy agents
# Iteration 80: 239 happy agents
# Iteration 81: 243 happy agents
# Iteration 82: 248 happy agents
# Iteration 83: 253 happy agents
# Iteration 84: 255 happy agents
# Iteration 85: 256 happy agents
# Iteration 86: 257 happy agents
# Iteration 87: 263 happy agents
# Iteration 88: 268 happy agents
# Iteration 89: 262 happy agents
# Iteration 90: 265 happy agents
# Iteration 91: 267 happy agents
# Iteration 92: 278 happy agents
# Iteration 93: 277 happy agents
# Iteration 94: 281 happy agents
# Iteration 95: 282 happy agents
# Iteration 96: 285 happy agents
# Iteration 97: 284 happy agents
# Iteration 98: 279 happy agents
# Iteration 99: 278 happy agents
# Iteration 100: 278 happy agents
# Iteration 101: 279 happy agents
# Iteration 102: 279 happy agents
# Iteration 103: 279 happy agents
# Iteration 104: 279 happy agents
# Iteration 105: 281 happy agents
# Iteration 106: 285 happy agents
# Iteration 107: 288 happy agents
# Iteration 108: 285 happy agents
# Iteration 109: 286 happy agents
# Iteration 110: 287 happy agents
# Iteration 111: 286 happy agents
# Iteration 112: 287 happy agents
# Iteration 113: 288 happy agents
# Iteration 114: 291 happy agents
# Iteration 115: 288 happy agents
# Iteration 116: 291 happy agents
# Iteration 117: 291 happy agents
# Iteration 118: 291 happy agents
# Iteration 119: 284 happy agents
# Iteration 120: 283 happy agents
# Iteration 121: 282 happy agents
# Iteration 122: 285 happy agents
# Iteration 123: 288 happy agents
# Iteration 124: 289 happy agents
# Iteration 125: 292 happy agents
# Iteration 126: 293 happy agents
# Iteration 127: 293 happy agents
# Iteration 128: 293 happy agents
# Iteration 129: 292 happy agents
# Iteration 130: 293 happy agents
# Iteration 131: 293 happy agents
# Iteration 132: 293 happy agents
# Iteration 133: 293 happy agents
# Iteration 134: 294 happy agents
# Iteration 135: 294 happy agents
# Iteration 136: 294 happy agents
# Iteration 137: 294 happy agents
# Iteration 138: 294 happy agents
# Iteration 139: 294 happy agents
# Iteration 140: 294 happy agents
# Iteration 141: 294 happy agents
# Iteration 142: 292 happy agents
# Iteration 143: 292 happy agents
# Iteration 144: 294 happy agents
# Iteration 145: 294 happy agents
# Iteration 146: 294 happy agents
# Iteration 147: 294 happy agents
# Iteration 148: 293 happy agents
# Iteration 149: 293 happy agents
# Iteration 150: 293 happy agents
# Iteration 151: 294 happy agents
# Iteration 152: 294 happy agents
# Iteration 153: 294 happy agents
# Iteration 154: 295 happy agents
# Iteration 155: 296 happy agents
# Iteration 156: 296 happy agents
# Iteration 157: 296 happy agents
# Iteration 158: 296 happy agents
# Iteration 159: 298 happy agents
# Iteration 160: 299 happy agents
# Iteration 161: 299 happy agents
# Iteration 162: 299 happy agents
# Iteration 163: 300 happy agents
# Iteration 164: 300 happy agents
# Iteration 165: 300 happy agents
# Iteration 166: 300 happy agents
# Iteration 167: 300 happy agents
# Iteration 168: 300 happy agents
# Iteration 169: 300 happy agents
# Iteration 170: 300 happy agents
# Iteration 171: 300 happy agents
# Iteration 172: 300 happy agents
# Iteration 173: 300 happy agents
# Iteration 174: 300 happy agents
# Iteration 175: 300 happy agents
# Iteration 176: 300 happy agents
# Iteration 177: 300 happy agents
# Iteration 178: 300 happy agents
# Iteration 179: 300 happy agents
# Iteration 180: 300 happy agents
# Iteration 181: 300 happy agents
# Iteration 182: 300 happy agents
# Iteration 183: 300 happy agents
# Iteration 184: 300 happy agents
# Iteration 185: 300 happy agents
# Iteration 186: 300 happy agents
# Iteration 187: 300 happy agents
# Iteration 188: 300 happy agents
# Iteration 189: 300 happy agents
# Iteration 190: 300 happy agents
# Iteration 191: 300 happy agents
# Iteration 192: 300 happy agents
# Iteration 193: 300 happy agents
# Iteration 194: 300 happy agents
# Iteration 195: 300 happy agents
# Iteration 196: 300 happy agents
# Iteration 197: 300 happy agents
# Iteration 198: 300 happy agents
# Iteration 199: 300 happy agents

# %%
# Plot the happiness graph too
fig = model.plot_happiness(return_fig=True)
fig.savefig(os.path.join("results", "Happiness.pdf"), bbox_inches='tight', dpi=128)
fig.show()
# Out:
# /var/folders/cp/2gftcqdj6w1gfgb05n_ghng40000gr/T/ipykernel_64078/3703605950.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
